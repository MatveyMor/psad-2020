# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
import pandas as pd
import seaborn as sns
import statsmodels

# %%
data = pd.read_csv('corona.csv', header=None)

# %%
data
# Out:
#                  0           1              2
# 0           Страна  заболевшие  выздоровевшие
# 1         германия        2078             25
# 2            дания         617              1
# 3         малайзия         149             26
# 4          австрия         302              4
# 5             ирак          71             15
# 6            китай       80932          62901
# 7           италия       12462           1045
# 8              сша        1663             12
# 9         сингапур         178             96
# 10       австралия         128             21
# 11  великобритания         459             19
# 12         бахрейн         195             35
# 13        норвегия         702              1
# 14           корея        7869            333
# 15         франция        2284             12
# 16          кувейт          80              5
# 17           индия          73              4
# 18         таиланд          70             34
# ...
